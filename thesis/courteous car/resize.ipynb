# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('lane.png')

# %%
height, width = img.shape[:2]

# %%
height
# Out:
# 300

# %%
width
# Out:
# 300

# %%
shrink = cv2.resize(img, None, fx=1/10, fy=1/30, interpolation=cv2.INTER_AREA)

# %%
cv2.imwrite('lane2.png',shrink)
# Out:
# True

# %%
plt.imshow(img)
